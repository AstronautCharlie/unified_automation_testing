# %% [markdown]
# The purpose of this notebook is to check the analysis rendered by prompt 3, listed in `prompt_3_output.txt`

# %%
import sys, os
sys.path.insert(0, os.path.abspath("..")) # Make sure `utils.py` in the parent directory is importable 

from utils import load_all_adl
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 import sys, os
# ----> 2 sys.path.insert(0, os.path.abspath("..")) # Make sure `utils.py` in the parent directory is importable
#       4 from utils import load_all_adl
#
# File /opt/homebrew/Cellar/python@3.11/3.11.14_3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/posixpath.py:404, in abspath(path)
#     402         cwd = os.getcwdb()
#     403     else:
# --> 404         cwd = os.getcwd()
#     405     path = join(cwd, path)
#     406 return normpath(path)
#
# FileNotFoundError: [Errno 2] No such file or directory
